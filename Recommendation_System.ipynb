# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcelo0479/machinelearn/blob/main/Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To use this recommendation system you must download the following datasets:
#
# [Netflix](https://www.kaggle.com/shivamb/netflix-shows/download),
# [Prime video](https://www.kaggle.com/shivamb/amazon-prime-movies-and-tv-shows/download),
# [Disney +](https://www.kaggle.com/shivamb/disney-movies-and-tv-shows/download),
# [Hulu](https://www.kaggle.com/shivamb/hulu-movies-and-tv-shows/download)

# %% [markdown]
# In this recommendation system we are using the machine learning tecnich of NLP

# %% [markdown]
# # Recommendation system for a specific streaming service

# %% [markdown]
# First of all we need to import the libraries and the choosed database, then we need to treat these datas to be more apropriated to the algorithm.

# %%
import pandas as pd
import numpy as np

# %%
# Creating a function to choose the streaming service database
def database(csv_file):
  return pd.read_csv(csv_file)

# %%
df = database('hulu_titles.csv')

# %%
# Checking if theres is null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB

# %% [markdown]
# For NLP based prediction, natural language processing, the most critical datas in this database is in the rating, listed_in and description columns. However, we are going to do some treatment for the other columns as well to make them look better.

# %%
# Handling missing values
for c in df.columns:
  if c in ['rating', 'listed_in']:
    df[c].fillna(df.rating.mode()[0], inplace=True)
  elif c == 'description':
    df.drop(df[df[c].isnull()].index, inplace=True)
  elif df[c].isnull().sum() > 0:
    df[c].fillna('NoDataAvaliable', inplace=True)
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# For the purposes of this analysis, we need to pay more attention to the data in the description columns. obviously we can't have duplicate lines, but we also can't have descriptions that are too short and that match the title.

# %%
# Handling duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Descripiton column problems

# %%
# Description egual title
df[df.title == df.description]
# Out:
#      show_id   type                                              title  \
# 717     s718  Movie                                            UFC 262
# 768     s769  Movie                 UFC 261: Early Prelims and Prelims
# 2146   s2147  Movie  NASA's Giant Leaps: Past and Future - Celebrat...
#
#              director             cast          country      date_added  \
# 717   NoDataAvaliable  NoDataAvaliable  NoDataAvaliable    May 15, 2021
# 768   NoDataAvaliable  NoDataAvaliable  NoDataAvaliable  April 24, 2021
# 2146  NoDataAvaliable  NoDataAvaliable  NoDataAvaliable   July 19, 2019
#
#       release_year rating         duration  \
# 717           2021  TV-14  NoDataAvaliable
# 768           2021  TV-14  NoDataAvaliable
# 2146          2019  TV-14  NoDataAvaliable
#
#                                 listed_in  \
# 717                                Sports
# 768                                Sports
# 2146  Documentaries, Science & Technology
#
#                                             description
# 717                                             UFC 262
# 768                  UFC 261: Early Prelims and Prelims
# 2146  NASA's Giant Leaps: Past and Future - Celebrat...

# %%
df.drop(df[df.title == df.description].index, inplace=True)

# %%
# Noise in description
smalls_descrip = []
for i in df.index:
  if len(df.description[i]) < 20:
    smalls_descrip.append(i)
df.loc[smalls_descrip]
# Out:
#      show_id   type   title         director             cast  \
# 1596   s1597  Movie  Soccer  NoDataAvaliable  NoDataAvaliable
#
#               country     date_added  release_year rating         duration  \
# 1596  NoDataAvaliable  June 12, 2020          2017  TV-14  NoDataAvaliable
#
#      listed_in    description
# 1596    Sports  Soccer games.

# %%
df.drop(df.loc[smalls_descrip].index, inplace=True)

# %%
# Resetting the index to avoid problems with algorithm results
df.reset_index(inplace=True)

# %%
# Creating some new columns to help the prediction algorithm.
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}
df["ratings_ages"]= df["rating"].replace(ratings_ages)
df['gender_ratings_ages_and_description'] = df.listed_in + ', ' + df.ratings_ages + ', ' + df.description

# %%
# Importing the algorithms
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# Applying the algorithms
tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix = tfidf.fit_transform(df['gender_ratings_ages_and_description'])

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

index = pd.Series(df.index, index=df.title)

# %%
# Creating a function to calculate 10 recommendation based in a title
def recommendations(title, cosine_sim=cosine_sim):
  idx = index[title]

  sim_scores = list(enumerate(cosine_sim[idx]))
  sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse =True)
  sim_scores = sim_scores[1:11]
  movie_index = [i[0] for i in sim_scores]

  df_titles = df.title.iloc[movie_index]

  df_sim_scores = pd.DataFrame(sim_scores).set_index(0)
  df_sim_scores.rename(columns = {1 : 'sim_score'}, inplace=True)
  
  return pd.concat([df_titles, df_sim_scores], axis=1)

# %%
title_test = df.title[np.random.randint(0, len(df))]
title_test
# Out:
# 'Tokyo Ghoul'

# %%
recommendations(title_test)
# Out:
#                       title  sim_score
# 3016  Chrome Shelled Regios   0.118608
# 2797           In the Flesh   0.116681
# 1668       Digimon Frontier   0.098791
# 2976             Elfen Lied   0.097593
# 2761           Terraformars   0.097217
# 2106                    BEM   0.096044
# 817           28 Days Later   0.094423
# 2887    Parasyte: The Maxim   0.090183
# 2591         Akame ga Kill!   0.085423
# 296                  Solace   0.081027

# %% [markdown]
# # Recommendation system for all the streaming services.

# %% [markdown]
# For this porpose we need to join all the databases

# %%
df_netflix = pd.read_csv('netflix_titles.csv')
df_prime = pd.read_csv('amazon_prime_titles.csv')
df_disney = pd.read_csv('disney_plus_titles.csv')
df_hulu = pd.read_csv('hulu_titles.csv')

# %%
df_netflix['streaming'] = 'netflix'
df_prime['streaming'] = 'prime'
df_disney['streaming'] = 'disney +'
df_hulu['streaming'] = 'hulu'

# %%
df = pd.concat([df_netflix, df_prime, df_disney, df_hulu])

# %%
# Checking if theres is null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 3072
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       22998 non-null  object
#  1   type          22998 non-null  object
#  2   title         22998 non-null  object
#  3   director      14739 non-null  object
#  4   cast          17677 non-null  object
#  5   country       11499 non-null  object
#  6   date_added    13444 non-null  object
#  7   release_year  22998 non-null  int64
#  8   rating        22134 non-null  object
#  9   duration      22516 non-null  object
#  10  listed_in     22998 non-null  object
#  11  description   22994 non-null  object
#  12  streaming     22998 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.5+ MB

# %%
# handling missing values
for c in df.columns:
  if c in ['rating', 'listed_in']:
    df[c].fillna(df.rating.mode()[0], inplace=True)
  elif c == 'description':
    df.drop(df[df[c].isnull()].index, inplace=True)
  elif df[c].isnull().sum() > 0:
    df[c].fillna('NoDataAvaliable', inplace=True)
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# streaming       0
# dtype: int64

# %%
# Handling duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.title.duplicated().sum()
# Out:
# 881

# %%
df.drop_duplicates(subset='title', inplace=True)

# %%
# Description egual title
df[df.title == df.description]
# Out:
#      show_id     type                                              title  \
# 2563   s2564  TV Show                                         Elfen Lied
# 6416   s6417    Movie                     Title before 1C onboarding - 5
# 6930   s6931    Movie                            Title Post onboarding 8
# 8501   s8502    Movie                                    Act 6 - Title 1
# 8502   s8503    Movie                                    Act 5 - Title 1
# 9001   s9002  TV Show                                    Roadkill Garage
# 9557   s9558    Movie                         Date Night: World Premiere
# 9558   s9559    Movie                         Date Night: Making a Scene
# 717     s718    Movie                                            UFC 262
# 768     s769    Movie                 UFC 261: Early Prelims and Prelims
# 2146   s2147    Movie  NASA's Giant Leaps: Past and Future - Celebrat...
#
#              director                                               cast  \
# 2563  NoDataAvaliable                    Kira Vincent-Davis, Adam Conlon
# 6416  NoDataAvaliable                                            1, 2, 3
# 6930                1                                                  1
# 8501                1                                                  1
# 8502                1                                                  1
# 9001  NoDataAvaliable                                    NoDataAvaliable
# 9557       Shawn Levy  Steve Carell,  Tina Fey,  Mark Wahlberg,  Tara...
# 9558       Shawn Levy  Steve Carell,  Tina Fey,  Mark Wahlberg,  Tara...
# 717   NoDataAvaliable                                    NoDataAvaliable
# 768   NoDataAvaliable                                    NoDataAvaliable
# 2146  NoDataAvaliable                                    NoDataAvaliable
#
#               country       date_added  release_year rating         duration  \
# 2563  NoDataAvaliable  NoDataAvaliable          2005  TV-NR         1 Season
# 6416  NoDataAvaliable  NoDataAvaliable          2021    18+            3 min
# 6930  NoDataAvaliable  NoDataAvaliable          2021    18+           61 min
# 8501  NoDataAvaliable  NoDataAvaliable          2021    ALL           61 min
# 8502  NoDataAvaliable  NoDataAvaliable          2021    ALL           61 min
# 9001  NoDataAvaliable  NoDataAvaliable          2017  TV-NR         1 Season
# 9557  NoDataAvaliable  NoDataAvaliable          2010     NR            5 min
# 9558  NoDataAvaliable  NoDataAvaliable          2010     NR           10 min
# 717   NoDataAvaliable     May 15, 2021          2021  TV-MA  NoDataAvaliable
# 768   NoDataAvaliable   April 24, 2021          2021  TV-MA  NoDataAvaliable
# 2146  NoDataAvaliable    July 19, 2019          2019  TV-MA  NoDataAvaliable
#
#                                 listed_in  \
# 2563                                Anime
# 6416                                Drama
# 6930                               Action
# 8501                               Action
# 8502                               Action
# 9001                   Sports, Unscripted
# 9557                               Comedy
# 9558                               Comedy
# 717                                Sports
# 768                                Sports
# 2146  Documentaries, Science & Technology
#
#                                             description streaming
# 2563                                         Elfen Lied     prime
# 6416                     Title before 1C onboarding - 5     prime
# 6930                            Title Post onboarding 8     prime
# 8501                                    Act 6 - Title 1     prime
# 8502                                    Act 5 - Title 1     prime
# 9001                                    Roadkill Garage     prime
# 9557                         Date Night: World Premiere     prime
# 9558                         Date Night: Making a Scene     prime
# 717                                             UFC 262      hulu
# 768                  UFC 261: Early Prelims and Prelims      hulu
# 2146  NASA's Giant Leaps: Past and Future - Celebrat...      hulu

# %%
df.drop(df[df.title == df.description].index, inplace=True)

# %%
# Noise in description
smalls_descrip = []
for i in df.index:
  if len(df.description[i]) < 20:
    smalls_descrip.append(i)
df.loc[smalls_descrip]
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie                              Dick Johnson Is Dead
# 0         s1    Movie                               The Grand Seduction
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 0         s1    Movie                    Ricky Velez: Here's Everything
# 1         s2  TV Show                                     Blood & Water
# ...      ...      ...                                               ...
# 3071   s3072    Movie                           Bigfoot: The Conspiracy
# 3071   s3072  TV Show                                 The Twilight Zone
# 3072   s3073    Movie                                              Riot
# 3072   s3073    Movie                                           Big Sur
# 3072   s3073  TV Show                               Tokyo Magnitude 8.0
#
#                                director  \
# 0                       Kirsten Johnson
# 0                          Don McKellar
# 0     Alonso Ramirez Ramos, Dave Wasson
# 0                       NoDataAvaliable
# 1                       NoDataAvaliable
# ...                                 ...
# 3071                       Chris Simoes
# 3071                    NoDataAvaliable
# 3072                          John Lyde
# 3072                     Michael Polish
# 3072                    NoDataAvaliable
#
#                                                    cast          country  \
# 0                                       NoDataAvaliable    United States
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent           Canada
# 0     Chris Diamantopoulos, Tony Anselmo, Tress MacN...  NoDataAvaliable
# 0                                       NoDataAvaliable  NoDataAvaliable
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# ...                                                 ...              ...
# 3071  Chris Simoes, Dave Watkins, Betsy Mitchell, Jo...  NoDataAvaliable
# 3071                                    NoDataAvaliable    United States
# 3072  Matthew Reese, Dolph Lundgren, Danielle Chuchr...  NoDataAvaliable
# 3072  Jean-Marc Barr, Kate Bosworth, Josh Lucas, Rad...  NoDataAvaliable
# 3072                                    NoDataAvaliable            Japan
#
#               date_added  release_year rating         duration  \
# 0     September 25, 2021          2020  PG-13           90 min
# 0         March 30, 2021          2014  TV-MA          113 min
# 0      November 26, 2021          2016   TV-G           23 min
# 0       October 24, 2021          2021  TV-MA  NoDataAvaliable
# 1     September 24, 2021          2021  TV-MA        2 Seasons
# ...                  ...           ...    ...              ...
# 3071     NoDataAvaliable          2020    16+           77 min
# 3071     NoDataAvaliable          1959  TV-PG        5 Seasons
# 3072     January 1, 2020          2015  TV-MA           88 min
# 3072     NoDataAvaliable          2013      R           80 min
# 3072     NoDataAvaliable          2009  TV-14         1 Season
#
#                                             listed_in  \
# 0                                       Documentaries
# 0                                       Comedy, Drama
# 0                                   Animation, Family
# 0                                    Comedy, Stand Up
# 1     International TV Shows, TV Dramas, TV Mysteries
# ...                                               ...
# 3071                         Action, Horror, Suspense
# 3071              Classics, Science Fiction, Thriller
# 3072                               Action & Adventure
# 3072                                   Drama, Romance
# 3072                      Anime, Drama, International
#
#                                             description streaming
# 0     As her father nears the end of his life, filmm...   netflix
# 0     A small fishing village must procure a local d...     prime
# 0      Join Mickey and the gang as they duck the halls!  disney +
# 0     ​Comedian Ricky Velez bares it all with his ho...      hulu
# 1     After crossing paths at a party, a Cape Town t...   netflix
# ...                                                 ...       ...
# 3071  This film follows a retired Border Patrol agen...     prime
# 3071  Rod Serling's seminal anthology series focused...      hulu
# 3072  Seeking vengeance for the murder of his wife, ...   netflix
# 3072  A recounting of Jack Kerouac's three sojourns ...     prime
# 3072  The devastation is unleashed in the span of se...      hulu
#
# [56071 rows x 13 columns]

# %%
df.drop(df.loc[smalls_descrip].index, inplace=True)

# %%
# Development remains in the description
df[df.cast.apply(lambda x: 'Test' in x)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, streaming]
# Index: []

# %%
df_tests = df[(df.cast.apply(lambda x: 'Test' in x)) & (df.country == 'NoDataAvaliable')]
df_tests
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, streaming]
# Index: []

# %%
df.drop(df_tests.index, inplace=True)

# %%
# Resetting the index to avoid problems with algorithm results
df.reset_index(inplace=True)

# %%
# Creating some new columns to help the prediction algorithm.
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}
df["ratings_ages"]= df["rating"].replace(ratings_ages)
df['gender_ratings_ages_and_description'] = df.listed_in + ', ' + df.ratings_ages + ', ' + df.description

# %%
tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix = tfidf.fit_transform(df['gender_ratings_ages_and_description'])

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

index = pd.Series(df.index, index=df.title)

# %%
def recommendations(title, cosine_sim=cosine_sim):
  idx = index[title]

  sim_scores = list(enumerate(cosine_sim[idx]))
  sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse =True)
  sim_scores = sim_scores[1:11]
  movie_index = [i[0] for i in sim_scores]

  df_titles_streamming = df[['title', 'streaming']].iloc[movie_index]

  df_sim_scores = pd.DataFrame(sim_scores).set_index(0)
  df_sim_scores.rename(columns = {1 : 'sim_score'}, inplace=True)
  
  return pd.concat([df_titles_streamming, df_sim_scores], axis=1)

# %%
title_test = df.title[np.random.randint(0, len(df))]
title_test
# Out:
# 'What Happens in Vegas (Extended Edition)'

# %%
recommendations(title_test)
# Out:
#                                   title streaming  sim_score
# 1018              What Happens in Vegas     prime   0.874151
# 934                    The Wedding Trip     prime   0.129801
# 61           Sam Kinison: Live in Vegas   netflix   0.122722
# 216                         Shark Night   netflix   0.116078
# 56                      A Second Chance   netflix   0.111976
# 998                John Tucker Must Die     prime   0.098686
# 1016                        White Night     prime   0.096693
# 994                      Knight and Day     prime   0.096280
# 818                  Two and a Half Men     prime   0.093694
# 1050  Knight and Day (Extended Edition)     prime   0.092833

# %% [markdown]
# I will come back to this recommender system in the future to try to improve its results by using other NLP algorithms and changing their hyperparameters.
